# %%
import pandas as pd

# %%
df = pd.read_parquet('../assets/sample.parquet')

# %%
df
# Out:
#                              email name   gender  created_at  last_visited_at  \
# 0    abbigail.i2arj4zn@example.net  何瀚福  unknown  1561828503       1719468723
# 1       abdul.6d92e6bs@example.org  冯娜盈  unknown  1561899573       1718932353
# 2       abdul.c24lxfwi@example.net  杨语凤  unknown  1561808454       1717233294
# 3    abdullah.1pv6ugtr@example.net  吕雨珍  unknown  1561891044       1717046484
# 4        abel.76b5fr5i@example.com  陈雅儿  unknown  1561884685       1718600545
# ..                             ...  ...      ...         ...              ...
# 995     reyna.qn2g5j96@example.org  谭秋风  unknown  1561924794       1717643394
# 996     rhett.mwnipq0l@example.com  邱任平  unknown  1561860273       1719037533
# 997  richmond.syk4rmp4@example.com  张鼎遥  unknown  1561899094       1717149094
# 998    rickie.2eprv9va@example.com  付寒云  unknown  1561926677       1718831597
# 999      rita.hs7ufnr9@example.org  邓鼎宇  unknown  1561932203       1717055843
#
# ...

# %%
df.describe()
# Out:
#          created_at  last_visited_at  last_watched_at  \
# count  1.000000e+03     1.000000e+03     1.000000e+03
# mean   1.561854e+09     1.718182e+09     1.715551e+09
# std    4.923691e+04     7.497247e+05     2.265033e+06
# min    1.561772e+09     1.716895e+09     1.711714e+09
# 25%    1.561811e+09     1.717550e+09     1.713627e+09
# 50%    1.561853e+09     1.718182e+09     1.715511e+09
# 75%    1.561897e+09     1.718814e+09     1.717578e+09
# max    1.561939e+09     1.719480e+09     1.719428e+09
#
#        last_email_notification  last_in_app_notification  \
# count             1.000000e+03              1.000000e+03
# mean              1.717596e+09              1.718835e+09
# std               1.129392e+06              3.625031e+05
# min               1.715606e+09              1.718184e+09
# 25%               1.716602e+09              1.718518e+09
# 50%               1.717611e+09              1.718848e+09
# 75%               1.718580e+09              1.719156e+09
# ...

# %%
df[df['created_at'].dtype >= '2024-01-25']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[df['created_at'] >= '2024-01-25']
#
# File ~/rust/geektime-rust/taotie/notebooks/.venv/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/rust/geektime-rust/taotie/notebooks/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~/rust/geektime-rust/taotie/notebooks/.venv/lib/python3.12/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...
